# %% [markdown]
# ## FEniCSx Colab Template (Course Version)
#
# This notebook is the **official starting point** for the course.
#
# **Do not modify this notebook.**
# Copy it when starting a new assignment.
#
# ---
#
# ### Cell 1 — Environment check
# This verifies that FEniCSx, MPI, and micromamba are correctly installed.

# %%
# %%fenicsx --info

# %% [markdown]
# ---
#
# ### Cell 2 — MPI sanity check
# This cell confirms that MPI parallel execution works as expected.
#
# Expected output: 4 lines (one per rank).

# %%
# %%fenicsx -np 4
#
# from mpi4py import MPI
# import dolfinx
#
# comm = MPI.COMM_WORLD
#
# print(
#     f"[rank {comm.rank}/{comm.size}] "
#     f"dolfinx={dolfinx.__version__}"
# )

# %% [markdown]
# ---
#
# ## Next steps
# - If both cells run without errors, your environment is ready.
# - Proceed to the next notebook for actual FEM computations.
#
# If something fails, re-run **bootstrap_colab.ipynb**.
